# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID         City Country                 Date      Lat       Lng  \
# 0        0     Cherskiy      RU  2022-09-22 05:43:14  68.7500  161.3000
# 1        1    Kununurra      AU  2022-09-22 05:46:04 -15.7667  128.7333
# 2        2        Yanji      CN  2022-09-22 05:46:04  42.9075  129.5078
# 3        3  Yellowknife      CA  2022-09-22 05:42:41  62.4560 -114.3525
# 4        4        Gagra      GE  2022-09-22 05:50:28  43.3283   40.2239
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     45.55        54           3        4.81           clear sky
# 1    100.38        30          40        4.61    scattered clouds
# 2     70.45        47          51        6.93       broken clouds
# 3     52.32        76          20        5.75          few clouds
# 4     61.72        91         100        8.16     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
max_temp = float(input("max temp?"))
min_temp = float(input("min temp"))
# Out:
# max temp?110
# min temp80

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
city_data_df = city_data_df.loc[(city_data_df['Max Temp']>=min_temp)&(city_data_df['Max Temp']<max_temp)]
city_data_df.head()
# Out:
#     City_ID         City Country                 Date      Lat       Lng  \
# 1         1    Kununurra      AU  2022-09-22 05:46:04 -15.7667  128.7333
# 7         7    Sanmenxia      CN  2022-09-22 05:50:29  34.7747  111.1814
# 14       14        Kapaa      US  2022-09-22 05:43:23  22.0752 -159.3190
# 18       18  Kloulklubed      PW  2022-09-22 05:50:32   7.0419  134.2556
# 23       23       Padang      ID  2022-09-22 05:42:45  -0.9492  100.3543
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 1     100.38        30          40        4.61    scattered clouds
# 7      81.59        17          36       20.22    scattered clouds
# 14     82.38        85          40       11.50       moderate rain
# 18     84.76        67         100        8.23     overcast clouds
# 23     82.45        67          80        5.95       broken clouds

# %%
# 4a. Determine if there are any empty rows.
check = city_data_df.isna().sum()
check
# Out:
# City_ID                0
# City                   0
# Country                0
# Date                   0
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df=city_data_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 1     Kununurra      AU    100.38    scattered clouds -15.7667  128.7333
# 7     Sanmenxia      CN     81.59    scattered clouds  34.7747  111.1814
# 14        Kapaa      US     82.38       moderate rain  22.0752 -159.3190
# 18  Kloulklubed      PW     84.76     overcast clouds   7.0419  134.2556
# 23       Padang      ID     82.45       broken clouds  -0.9492  100.3543
# 26        Matay      EG     82.54           clear sky  28.4190   30.7792
# 34       Najran      SA     84.85    scattered clouds  17.4924   44.1277
# 49       Sabang      ID     81.86     overcast clouds   5.8933   95.3214
# 57   Butaritari      KI     81.97     overcast clouds   3.0707  172.7902
# 61  Bandarbeyla      SO     85.30       broken clouds   9.4942   50.8122
#
#    Hotel Name
# 1
# 7
# 14
# 18
# 23
# 26
# 34
# 49
# 57
# 61

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found..skipping")
    # 6c. Get latitude and longitude from DataFrame

    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    

    # 6e. Make request and retrieve the JSON data from the search. 
   
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
# Out:
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping
# Hotel not found..skipping

# %%
hotel_df.head(50)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 1        Kununurra      AU    100.38    scattered clouds -15.7667  128.7333
# 7        Sanmenxia      CN     81.59    scattered clouds  34.7747  111.1814
# 14           Kapaa      US     82.38       moderate rain  22.0752 -159.3190
# 18     Kloulklubed      PW     84.76     overcast clouds   7.0419  134.2556
# 23          Padang      ID     82.45       broken clouds  -0.9492  100.3543
# 26           Matay      EG     82.54           clear sky  28.4190   30.7792
# 34          Najran      SA     84.85    scattered clouds  17.4924   44.1277
# 49          Sabang      ID     81.86     overcast clouds   5.8933   95.3214
# 57      Butaritari      KI     81.97     overcast clouds   3.0707  172.7902
# 61     Bandarbeyla      SO     85.30       broken clouds   9.4942   50.8122
# 63       Bathsheba      BB     83.01    scattered clouds  13.2167  -59.5167
# 67      Balkanabat      TM     93.27           clear sky  39.5108   54.3671
# 69         Biloela      AU     84.15    scattered clouds -24.4167  150.5000
# 73        Meulaboh      ID     85.46       broken clouds   4.1363   96.1285
# 87        Araouane      ML     86.81          few clouds  18.9048   -3.5265
# 106       Karratha      AU     87.01           clear sky -20.7377  116.8463
# 117      Hithadhoo      MV     81.97    scattered clouds  -0.6000   73.0833
# 119      Changping      CN     80.24           clear sky  40.2186  116.2197
# 120    Keti Bandar      PK     85.03    scattered clouds  24.1447   67.4497
# 121       Bengkulu      ID     81.46       broken clouds  -3.8004  102.2655
# 127         Dingle      PH     86.95     overcast clouds  10.9995  122.6711
# 131     Quang Ngai      VN     83.75       moderate rain  15.1167  108.8000
# 141       Victoria      HK     91.45    scattered clouds  22.2855  114.1577
# 145   Torbat-E Jam      IR     82.40           clear sky  35.2440   60.6225
# 147          Adrar      MR     85.80     overcast clouds  20.5022  -10.0711
# 161            Sur      OM     89.42           clear sky  22.5667   59.5289
# 165      Mount Isa      AU     85.77     overcast clouds -20.7333  139.5000
# 168       Chakulia      IN     87.55    scattered clouds  22.4833   86.7167
# 169      Pamanukan      ID     86.77     overcast clouds  -6.2842  107.8106
# 170      Wattegama      LK     95.61       broken clouds   6.7989   81.4808
# 175     Perbaungan      ID     86.11     overcast clouds   3.5679   98.9560
# 176     Georgetown      MY     83.89          few clouds   5.4112  100.3354
# 177   Komsomolskiy      UZ     83.12           clear sky  40.4272   71.7189
# 189        Ganzhou      CN     81.99     overcast clouds  28.8184  115.4327
# 194          Along      IN     83.19       broken clouds  28.1667   94.7667
# 210        Kavieng      PG     83.25    scattered clouds  -2.5744  150.7967
# 211         Khurda      IN     87.71       broken clouds  20.1833   85.6167
# 212       Ahuimanu      US     80.31       broken clouds  21.4447 -157.8378
# 214         Sinjai      ID     85.62          light rain  -5.1241  120.2530
# 216   Kudahuvadhoo      MV     82.53    scattered clouds   2.6708   72.8944
# 217     Santa Rosa      PH     83.10       moderate rain  14.3122  121.1114
# 219        Salalah      OM     82.49       broken clouds  17.0151   54.0924
# 224       Tessalit      ML     83.95    scattered clouds  20.1986    1.0114
# 237        Merauke      ID     82.17     overcast clouds  -8.4667  140.3333
# 257       Manadhoo      MV     81.91           clear sky   5.7667   73.3833
# 258          Kidal      ML     84.40       broken clouds  18.4411    1.4078
# 260     Tombouctou      ML     86.40           clear sky  20.0000   -3.0000
# 266          Binga      ZW     80.65    scattered clouds -17.6203   27.3414
# 276  Alice Springs      AU     85.55           clear sky -23.7000  133.8833
# 277      Nishihara      JP     87.46    scattered clouds  26.1842  127.7558
#
#                                    Hotel Name
# 1                             Hotel Kununurra
# 7                              Pengzhou Hotel
# 14        Sheraton Kauai Coconut Beach Resort
# 18                    Storyboard Beach Resort
# 23                             Mercure Padang
# 26                                 Nag Aespen
# 34                          محمد هادي ال فطيح
# 49                                Hotel Citra
# 57                         Isles Sunset Lodge
# 61                                JABIR HOTEL
# 63                             Atlantis Hotel
# 67                             Nebitchi Hotel
# 69                     Silo Motor Inn Biloela
# 73                                  Kost Pria
# 87
# 106                      ibis Styles Karratha
# 117                         Scoop Guest House
# 119                            Huachang Hotel
# 120                    Haji laloo memon house
# 121                      Grage Hotel Bengkulu
# 127                           SEGAYA PROPERTY
# 131                             Central Hotel
# 141                              Mini Central
# 145                            White building
# 147
# 161                           Sur Plaza Hotel
# 165                 ibis Styles Mt Isa Verona
# 168                                       BKD
# 169                 Paris Day Hotel Pamanukan
# 170
# 175                              Bendang Lama
# 176                            Cititel Penang
# 177                                 Ikathouse
# 189                      Zhanqian Grand Hotel
# 194                                Hotel West
# 210                       Nusa Island Retreat
# 211                             Bagbaan Villa
# 212                       Paradise Bay Resort
# 214                             Wisma Sandika
# 216           Niyama Private Islands Maldives
# 217                Erlyn’s Sta Rosa City Home
# 219  HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# 224
# 237
# 257                         Bon Abri maldives
# 258
# 260
# 266                        Lakeview Inn Binga
# 276                Desert Palms Alice Springs
# 277                         Minshuku Agaihama

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df["Hotel Name"].isnull().count()
# Out:
# 141

# %%
import numpy as np

# %%
hotel_df["Hotel Name"].replace('',np.nan,inplace=True)
hotel_df = hotel_df.dropna()
hotel_df.head(50)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 1        Kununurra      AU    100.38    scattered clouds -15.7667  128.7333
# 7        Sanmenxia      CN     81.59    scattered clouds  34.7747  111.1814
# 14           Kapaa      US     82.38       moderate rain  22.0752 -159.3190
# 18     Kloulklubed      PW     84.76     overcast clouds   7.0419  134.2556
# 23          Padang      ID     82.45       broken clouds  -0.9492  100.3543
# 26           Matay      EG     82.54           clear sky  28.4190   30.7792
# 34          Najran      SA     84.85    scattered clouds  17.4924   44.1277
# 49          Sabang      ID     81.86     overcast clouds   5.8933   95.3214
# 57      Butaritari      KI     81.97     overcast clouds   3.0707  172.7902
# 61     Bandarbeyla      SO     85.30       broken clouds   9.4942   50.8122
# 63       Bathsheba      BB     83.01    scattered clouds  13.2167  -59.5167
# 67      Balkanabat      TM     93.27           clear sky  39.5108   54.3671
# 69         Biloela      AU     84.15    scattered clouds -24.4167  150.5000
# 73        Meulaboh      ID     85.46       broken clouds   4.1363   96.1285
# 106       Karratha      AU     87.01           clear sky -20.7377  116.8463
# 117      Hithadhoo      MV     81.97    scattered clouds  -0.6000   73.0833
# 119      Changping      CN     80.24           clear sky  40.2186  116.2197
# 120    Keti Bandar      PK     85.03    scattered clouds  24.1447   67.4497
# 121       Bengkulu      ID     81.46       broken clouds  -3.8004  102.2655
# 127         Dingle      PH     86.95     overcast clouds  10.9995  122.6711
# 131     Quang Ngai      VN     83.75       moderate rain  15.1167  108.8000
# 141       Victoria      HK     91.45    scattered clouds  22.2855  114.1577
# 145   Torbat-E Jam      IR     82.40           clear sky  35.2440   60.6225
# 161            Sur      OM     89.42           clear sky  22.5667   59.5289
# 165      Mount Isa      AU     85.77     overcast clouds -20.7333  139.5000
# 168       Chakulia      IN     87.55    scattered clouds  22.4833   86.7167
# 169      Pamanukan      ID     86.77     overcast clouds  -6.2842  107.8106
# 175     Perbaungan      ID     86.11     overcast clouds   3.5679   98.9560
# 176     Georgetown      MY     83.89          few clouds   5.4112  100.3354
# 177   Komsomolskiy      UZ     83.12           clear sky  40.4272   71.7189
# 189        Ganzhou      CN     81.99     overcast clouds  28.8184  115.4327
# 194          Along      IN     83.19       broken clouds  28.1667   94.7667
# 210        Kavieng      PG     83.25    scattered clouds  -2.5744  150.7967
# 211         Khurda      IN     87.71       broken clouds  20.1833   85.6167
# 212       Ahuimanu      US     80.31       broken clouds  21.4447 -157.8378
# 214         Sinjai      ID     85.62          light rain  -5.1241  120.2530
# 216   Kudahuvadhoo      MV     82.53    scattered clouds   2.6708   72.8944
# 217     Santa Rosa      PH     83.10       moderate rain  14.3122  121.1114
# 219        Salalah      OM     82.49       broken clouds  17.0151   54.0924
# 257       Manadhoo      MV     81.91           clear sky   5.7667   73.3833
# 266          Binga      ZW     80.65    scattered clouds -17.6203   27.3414
# 276  Alice Springs      AU     85.55           clear sky -23.7000  133.8833
# 277      Nishihara      JP     87.46    scattered clouds  26.1842  127.7558
# 284          Seydi      TM     91.72           clear sky  39.4816   62.9137
# 287          Hobyo      SO     81.09       broken clouds   5.3505   48.5268
# 292        Samarai      PG     80.65     overcast clouds -10.6167  150.6667
# 299          Kieta      PG     80.08          light rain  -6.2167  155.6333
# 300      Nhulunbuy      AU     90.21    scattered clouds -12.2333  136.7667
# 302  Dan Khun Thot      TH     91.33     overcast clouds  15.2085  101.7714
# 303          Bayji      IQ     89.87     overcast clouds  34.9311   43.4870
#
#                                    Hotel Name
# 1                             Hotel Kununurra
# 7                              Pengzhou Hotel
# 14        Sheraton Kauai Coconut Beach Resort
# 18                    Storyboard Beach Resort
# 23                             Mercure Padang
# 26                                 Nag Aespen
# 34                          محمد هادي ال فطيح
# 49                                Hotel Citra
# 57                         Isles Sunset Lodge
# 61                                JABIR HOTEL
# 63                             Atlantis Hotel
# 67                             Nebitchi Hotel
# 69                     Silo Motor Inn Biloela
# 73                                  Kost Pria
# 106                      ibis Styles Karratha
# 117                         Scoop Guest House
# 119                            Huachang Hotel
# 120                    Haji laloo memon house
# 121                      Grage Hotel Bengkulu
# 127                           SEGAYA PROPERTY
# 131                             Central Hotel
# 141                              Mini Central
# 145                            White building
# 161                           Sur Plaza Hotel
# 165                 ibis Styles Mt Isa Verona
# 168                                       BKD
# 169                 Paris Day Hotel Pamanukan
# 175                              Bendang Lama
# 176                            Cititel Penang
# 177                                 Ikathouse
# 189                      Zhanqian Grand Hotel
# 194                                Hotel West
# 210                       Nusa Island Retreat
# 211                             Bagbaan Villa
# 212                       Paradise Bay Resort
# 214                             Wisma Sandika
# 216           Niyama Private Islands Maldives
# 217                Erlyn’s Sta Rosa City Home
# 219  HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# 257                         Bon Abri maldives
# 266                        Lakeview Inn Binga
# 276                Desert Palms Alice Springs
# 277                         Minshuku Agaihama
# 284                               Seydi oteli
# 287               Halane Hotel and Restaurent
# 292                                 Nuli Sapi
# 299                         Uruna Bay Retreat
# 300                   East Arnhem Real Estate
# 302                           Sai Thong Hotel
# 303                               دار الضيافة

# %%
# 8a. Create the output File (CSV)
output_data_file = 'WeatherPy_vacation.csv'

# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather<dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# 11b. Display the figure
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
