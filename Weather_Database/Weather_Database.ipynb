# %%
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key
import numpy as np

# %%
weather_df = pd.read_csv('../weather_data/cities.csv')
weather_df.head()
# Out:
#    City_ID        City Country                 Date      Lat       Lng  \
# 0        0  Bukachacha      RU  2022-09-21 04:04:40  52.9833  116.9167
# 1        1     Ushuaia      AR  2022-09-21 04:00:46 -54.8000  -68.3000
# 2        2      Bethel      US  2022-09-21 04:01:12  41.3712  -73.4140
# 3        3   Esperance      AU  2022-09-21 04:04:41 -33.8667  121.9000
# 4        4   Luancheng      CN  2022-09-21 04:04:41  37.8792  114.6517
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     53.26        49          36        7.07
# 1     35.10        93          85        8.57
# 2     63.75        78           0        3.94
# 3     67.26        50           0       11.23
# 4     79.29        37           2        6.58

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['cherskiy',
#  'taolanaro',
#  'kununurra',
#  'yanji',
#  'yellowknife',
#  'gagra',
#  'rikitea',
#  'kuzino',
#  'sanmenxia',
#  'umzimvubu',
#  'la ronge',
#  'atbasar',
#  'arraial do cabo',
#  'khatanga',
#  'mataura',
#  'ljungby',
#  'kapaa',
#  'geraldton',
#  'provideniya',
#  'torbay',
#  'kloulklubed',
#  'cassilandia',
#  'busselton',
#  'puerto ayora',
#  'cape town',
#  'padang',
#  'thompson',
#  'port alfred',
#  'matay',
#  'zacualpan',
#  'chokurdakh',
#  'barrow',
#  'east london',
#  'gayny',
#  'ribeira grande',
#  'tigil',
#  'najran',
#  'port lincoln',
#  'wangqing',
#  'punta arenas',
#  'upernavik',
#  'saint-philippe',
#  'bulolo',
#  'bluff',
#  'grindavik',
#  'kraliky',
#  'vila do maio',
#  'nome',
#  'lusambo',
#  'dikson',
#  'nouadhibou',
#  'illoqqortoormiut',
#  'sabang',
#  'amderma',
#  'ilulissat',
#  'bundaberg',
#  'hermanus',
#  'sindgi',
#  'avera',
#  'ziro',
#  'srednekolymsk',
#  'butaritari',
#  'qaanaaq',
#  'kaitangata',
#  'mirante do paranapanema',
#  'bandarbeyla',
#  'crixas',
#  'bathsheba',
#  'progreso',
#  'tenamaxtlan',
#  'jiaxing',
#  'balkanabat',
#  'ukiah',
#  'biloela',
#  'treinta y tres',
#  'koutiala',
#  'faanui',
#  'meulaboh',
#  'bredasdorp',
#  'vaini',
#  'asyut',
#  'muzhi',
#  'mantua',
#  'pevek',
#  'jamestown',
#  'sentyabrskiy',
#  'brisbane',
#  'cayenne',
#  'lata',
#  'walvis bay',
#  'lebu',
#  'dunedin',
#  'araouane',
#  'chapais',
#  'cabedelo',
#  'tasiilaq',
#  'turayf',
#  'boende',
#  'new norfolk',
#  'port elizabeth',
#  'hobart',
#  'mys shmidta',
#  'johnstown',
#  'leshukonskoye',
#  'inuvik',
#  'avarua',
#  'anadyr',
#  'platanos',
#  'richmond',
#  'rodionovo-nesvetayskaya',
#  'nemuro',
#  'aswan',
#  'karratha',
#  'yar-sale',
#  'ushuaia',
#  'hofn',
#  'saleaula',
#  'oda',
#  'atuona',
#  'rundu',
#  'sao filipe',
#  'san cristobal',
#  'ahero',
#  'beoumi',
#  'hithadhoo',
#  'rio gallegos',
#  'changping',
#  'keti bandar',
#  'maghama',
#  'bengkulu',
#  'elko',
#  'nanortalik',
#  'clyde river',
#  'tuktoyaktuk',
#  'san quintin',
#  'dingle',
#  'popondetta',
#  'palabuhanratu',
#  'wajima',
#  'castro',
#  'quang ngai',
#  'talnakh',
#  'brae',
#  'vardo',
#  'hamilton',
#  'varkaus',
#  'albany',
#  'soroti',
#  'bambous virieux',
#  'mar del plata',
#  'victoria',
#  'plettenberg bay',
#  'calabozo',
#  'the pas',
#  'torbat-e jam',
#  'pacific grove',
#  'adrar',
#  'fairbanks',
#  'kasongo-lunda',
#  'puerto narino',
#  'warqla',
#  'nyuksenitsa',
#  'kodiak',
#  'coos bay',
#  'neiafu',
#  'kasongo',
#  'faya',
#  'burica',
#  'ongandjera',
#  'harper',
#  'bondo',
#  'saint george',
#  'sur',
#  'belmonte',
#  'ahipara',
#  'alofi',
#  'mount isa',
#  'harnosand',
#  'kalemie',
#  'chakulia',
#  'pamanukan',
#  'wattegama',
#  'vila franca do campo',
#  'loanda',
#  'hatillo',
#  'rosetta',
#  'perbaungan',
#  'georgetown',
#  'komsomolskiy',
#  'aanekoski',
#  'havoysund',
#  'jijiga',
#  'zhezkazgan',
#  'sindor',
#  'husavik',
#  'tsihombe',
#  'nikolskoye',
#  'xichang',
#  'caxito',
#  'hilo',
#  'isangel',
#  'ganzhou',
#  'orlovskiy',
#  'port hawkesbury',
#  'saraland',
#  'ouadda',
#  'along',
#  'jinchang',
#  'lasa',
#  'toungoo',
#  'college',
#  'tabiauea',
#  'teya',
#  'carnarvon',
#  'barroualie',
#  'tiksi',
#  'porto novo',
#  'lagunas',
#  'acarau',
#  'severo-kurilsk',
#  'natal',
#  'santa maria',
#  'sokoni',
#  'viligili',
#  'attawapiskat',
#  'tual',
#  'ondorhaan',
#  'jumla',
#  'kavieng',
#  'khurda',
#  'ahuimanu',
#  'nikki',
#  'barentsburg',
#  'sinjai',
#  'placerville',
#  'kudahuvadhoo',
#  'meyungs',
#  'santa rosa',
#  'nizhneyansk',
#  'russell',
#  'salalah',
#  'camana',
#  'ust-tsilma',
#  'fortuna',
#  'ixtapa',
#  'tessalit',
#  'morgantown',
#  'coquimbo',
#  'selizharovo',
#  'inhambane',
#  'nata',
#  'souris',
#  'maarianhamina',
#  'vaitupu',
#  'noumea',
#  'portland',
#  'tumannyy',
#  'norman wells',
#  'mayo',
#  'sechura',
#  'merauke',
#  'serramanna',
#  'palana',
#  'cap malheureux',
#  'orotukan',
#  'saskylakh',
#  'lima',
#  'kingaroy',
#  'guerrero negro',
#  'iki-burul',
#  'mungwi',
#  'brugg',
#  'novobiryusinskiy',
#  'nyurba',
#  'mahebourg',
#  'klaksvik',
#  'uarini',
#  'iqaluit',
#  'botwood',
#  'belushya guba',
#  'wawa',
#  'manadhoo',
#  'kidal',
#  'souillac',
#  'tombouctou',
#  'masallatah',
#  'longlac',
#  'staryy nadym',
#  'praia da vitoria',
#  'santa fe',
#  'ndago',
#  'binga',
#  'kachug',
#  'tiznit',
#  'chuy',
#  'dolbeau',
#  'birjand',
#  'port-gentil',
#  'hurricane',
#  'benguela',
#  'ostrovnoy',
#  'port-cartier',
#  'alice springs',
#  'nishihara',
#  'saldanha',
#  'kesova gora',
#  'flinders',
#  'rawson',
#  'hovd',
#  'nova olinda do norte',
#  'seydi',
#  'hasaki',
#  'yaan',
#  'hobyo',
#  'katsuura',
#  'waddan',
#  'lolua',
#  'muravlenko',
#  'sosnovo-ozerskoye',
#  'samarai',
#  'jalingo',
#  'barranca',
#  'airai',
#  'tuatapere',
#  'luena',
#  'lompoc',
#  'kieta',
#  'nhulunbuy',
#  'barcelona',
#  'dan khun thot',
#  'bayji',
#  'khandyga',
#  'paita',
#  'bluefield',
#  'blagoyevo',
#  'georgiyevskoye',
#  'pronsk',
#  'beaupre',
#  'rafaela',
#  'kamenskoye',
#  'septemvri',
#  'kavaratti',
#  'boyolangu',
#  'oistins',
#  'comodoro rivadavia',
#  'viedma',
#  'sinnamary',
#  'kungurtug',
#  'kihei',
#  'mpika',
#  'grand river south east',
#  'trairi',
#  'elk city',
#  'chulman',
#  'gorontalo',
#  'cidreira',
#  'anuchino',
#  'prince rupert',
#  'kristiansund',
#  'verkhnevilyuysk',
#  'corsicana',
#  'upington',
#  'guabito',
#  'helena',
#  'kalmunai',
#  'farmington',
#  'ponta do sol',
#  'udimskiy',
#  'marystown',
#  'nantucket',
#  'lishan',
#  'benalla',
#  'taoudenni',
#  'la primavera',
#  'priladozhskiy',
#  'imbituba',
#  'khowst',
#  'aleksandrovsk-sakhalinskiy',
#  'ilhabela',
#  'yuli',
#  'wenling',
#  'tefe',
#  'darhan',
#  'the valley',
#  'tommot',
#  'ahumada',
#  'seredka',
#  'mecca',
#  'mae sot',
#  'constitucion',
#  'vestmannaeyjar',
#  'ketchikan',
#  'narsaq',
#  'jinxiang',
#  'seymchan',
#  'ulaanbaatar',
#  'puerto colombia',
#  'luanda',
#  'cabo san lucas',
#  'lazaro cardenas',
#  'mount gambier',
#  'yasnogorsk',
#  'minggang',
#  'ngukurr',
#  'hailey',
#  'hambantota',
#  'vangaindrano',
#  'mitu',
#  'luderitz',
#  'kuching',
#  'muros',
#  'corn island',
#  'veraval',
#  'naze',
#  'pangnirtung',
#  'evensk',
#  'moron',
#  'tabou',
#  'port blair',
#  'key largo',
#  'ballina',
#  'melnikovo',
#  'esperance',
#  'cambridge',
#  'qeshm',
#  'baruun-urt',
#  'katav-ivanovsk',
#  'morehead',
#  'korla',
#  'bereda',
#  'yabrud',
#  'takestan',
#  'codrington',
#  'wuwei',
#  'santa cruz cabralia',
#  'sangar',
#  'lesnoy',
#  'berlevag',
#  'suntar',
#  'tocopilla',
#  'bargal',
#  'dryden',
#  'wana',
#  'bethel',
#  'ulaangom',
#  'xiaoweizhai',
#  'beaufort',
#  'naryan-mar',
#  'chara',
#  'mountain home',
#  'longyearbyen',
#  'port antonio',
#  'biak',
#  'prieska',
#  'sao mateus',
#  'kadykchan',
#  'byron bay',
#  'sao joao da barra',
#  'athabasca',
#  'sandwick',
#  'ambatofinandrahana',
#  'bogorodskoye',
#  'maceio',
#  'ponnampet',
#  'kruisfontein',
#  'ihosy',
#  'aban',
#  'mundo nuevo',
#  'ayan',
#  'aklavik',
#  'vinh',
#  'manakara',
#  'lodja',
#  'puri',
#  'port victoria',
#  'antalaha',
#  'baiyin',
#  'eldikan',
#  'cockburn town',
#  'malaya vishera',
#  'maumere',
#  'sola',
#  'bolungarvik',
#  'mugango',
#  'vostok',
#  'waounde',
#  'samusu',
#  'yulara',
#  'nouakchott',
#  'gemena',
#  'valparaiso',
#  'champerico',
#  'houlton',
#  'coruripe',
#  'olafsvik',
#  'beroroha',
#  'lavrentiya',
#  'leeton',
#  'roma',
#  'buzmeyin',
#  'mazagao',
#  'samagaltay',
#  'tabukiniberu',
#  'port macquarie',
#  'saint anthony',
#  'swan river',
#  'francisco sa',
#  'luba',
#  'playas',
#  'opuwo',
#  'biltine',
#  'satitoa',
#  'jardim',
#  'ashcroft',
#  'marsh harbour',
#  'baghdad',
#  'kahului',
#  'amahai',
#  'batagay',
#  'bandar-e lengeh',
#  'tuggurt',
#  'half moon bay',
#  'karakose',
#  'keuruu',
#  'winnemucca',
#  'doische',
#  'tsabong',
#  'hammerfest',
#  'raga',
#  'panubigan',
#  'tilichiki',
#  'bambanglipuro',
#  'san andres',
#  'syracuse',
#  'palmer',
#  'guia de isora',
#  'bukachacha',
#  'nhamunda',
#  'toliary',
#  'kulhudhuffushi',
#  'vila velha',
#  'beni suef',
#  'axim',
#  'moerai',
#  'tarko-sale',
#  'beringovskiy',
#  'bloemfontein',
#  'puerto ayacucho',
#  'abha',
#  'maslova pristan',
#  'nizhnyaya tavda',
#  'scottsbluff',
#  'bonthe',
#  'benjamin hill',
#  'luchenza',
#  'chapleau',
#  'kota belud',
#  'sehithwa',
#  'sadiqabad',
#  'nikko',
#  'banyuwangi',
#  'buluang',
#  'qurayyat',
#  'zhangjiakou',
#  'san patricio',
#  'khormuj',
#  'pauini',
#  'te anau',
#  'rapid valley',
#  'piacabucu',
#  'waitati',
#  'balakhninskiy',
#  'itarema',
#  'takab',
#  'pokhara',
#  'ganganagar',
#  'rio de janeiro',
#  'ponot',
#  'haines junction',
#  'aykhal',
#  'joshimath',
#  'ust-nera',
#  'humaita',
#  'acapulco',
#  'ambilobe',
#  'roald',
#  'lumberton',
#  'quepos',
#  'kyle of lochalsh',
#  'poum',
#  'saint-joseph',
#  'zhangye',
#  'arlit',
#  'christchurch',
#  'lagoa',
#  'nekhayevskiy',
#  'vaitape',
#  'manggar',
#  'marzuq',
#  'mandalgovi',
#  'tucupita',
#  'uinskoye',
#  'oum hadjer',
#  'itoman',
#  'kaihua',
#  'ponto novo',
#  'matadi',
#  'port augusta',
#  'dubovskoye',
#  'turukhansk',
#  'kirkwall',
#  'ilheus',
#  'kayerkan',
#  'san carlos de bariloche',
#  'linchuan',
#  'bonavista',
#  'karakendzha',
#  'abu dhabi',
#  'fuerte olimpo',
#  'gallup',
#  'marovoay',
#  'estelle',
#  'san vicente',
#  'homer',
#  'port moresby',
#  'saint-pierre',
#  'gobabis',
#  'novikovo',
#  'codajas',
#  'yanam',
#  'leningradskiy',
#  'praia',
#  'dongkan',
#  'miramar',
#  'barreirinha',
#  'passo fundo',
#  'marcona',
#  'setubal',
#  'saint-medard-en-jalles',
#  'defiance',
#  'sidi bin nur',
#  'campbell river',
#  'tucuman',
#  'manado',
#  'beyla',
#  'bushehr',
#  'shibetsu',
#  'juiz de fora',
#  'kondinskoye',
#  'tsimlyansk',
#  'kirakira',
#  'senneterre',
#  'nizwa',
#  'chermoz',
#  'jarjis',
#  'puerto escondido',
#  'verkhoyansk',
#  'hihifo',
#  'makakilo city',
#  'hirara',
#  'bafilo',
#  'taunggyi',
#  'chernyshevskiy',
#  'shimoda',
#  'sitka',
#  'ambodifototra',
#  'richards bay',
#  'sao desiderio',
#  'otofuke',
#  'gamba',
#  'okhotsk',
#  'mombetsu',
#  'paramo',
#  'corinto',
#  'ust-koksa',
#  'amga',
#  'grootfontein',
#  'san ramon de la nueva oran',
#  'dickinson',
#  'laranjeiro',
#  'victor harbor',
#  'port hedland',
#  'nikolayevsk-na-amure',
#  'chor',
#  'comalcalco',
#  'manokwari',
#  'lewistown',
#  'roquetas de mar',
#  'shaping',
#  'peniche',
#  'gushikawa',
#  'tazovskiy',
#  'plaster rock',
#  'verkhnyaya maksakovka',
#  'puerto plata',
#  'skerries',
#  'chinsali',
#  'kashan',
#  'krasnouralsk',
#  'elbrus',
#  'itupiranga',
#  'gimli',
#  'jalu',
#  'fare',
#  'saint-francois',
#  'moree',
#  'trmice',
#  'namatanai',
#  'ipaba',
#  'dom pedrito',
#  'sokoto',
#  'balabac',
#  'enshi',
#  'lakatoro',
#  'elizabeth city',
#  'mayya',
#  'kuito',
#  'adre',
#  'camacha',
#  'encruzilhada do sul',
#  'amuntai',
#  'agadez',
#  'mutsu',
#  'kyshtovka',
#  'toora-khem',
#  'igarka',
#  'bell ville',
#  'mizdah',
#  'ust-kuyga',
#  'goderich',
#  'kassala',
#  'yomitan',
#  'klamath falls']

# %%
from config import weather_api_key
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if i%50==0 and i >= 50: 
        set_count += 1
        record_count = 1
        time.sleep(1)
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                            "Current Description": city_des
                       })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | kununurra
# Processing Record 4 of Set 1 | yanji
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | gagra
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | kuzino
# Processing Record 9 of Set 1 | sanmenxia
# Processing Record 10 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 1 | la ronge
# Processing Record 12 of Set 1 | atbasar
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | ljungby
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | geraldton
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | kloulklubed
# Processing Record 22 of Set 1 | cassilandia
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | padang
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | matay
# Processing Record 30 of Set 1 | zacualpan
# Processing Record 31 of Set 1 | chokurdakh
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | gayny
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | tigil
# Processing Record 37 of Set 1 | najran
# Processing Record 38 of Set 1 | port lincoln
# Processing Record 39 of Set 1 | wangqing
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | bulolo
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | grindavik
# Processing Record 46 of Set 1 | kraliky
# Processing Record 47 of Set 1 | vila do maio
# Processing Record 48 of Set 1 | nome
# Processing Record 49 of Set 1 | lusambo
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | nouadhibou
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | sabang
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | bundaberg
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | sindgi
# Processing Record 9 of Set 2 | avera
# Processing Record 10 of Set 2 | ziro
# Processing Record 11 of Set 2 | srednekolymsk
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | mirante do paranapanema
# Processing Record 16 of Set 2 | bandarbeyla
# Processing Record 17 of Set 2 | crixas
# Processing Record 18 of Set 2 | bathsheba
# Processing Record 19 of Set 2 | progreso
# Processing Record 20 of Set 2 | tenamaxtlan
# Processing Record 21 of Set 2 | jiaxing
# Processing Record 22 of Set 2 | balkanabat
# Processing Record 23 of Set 2 | ukiah
# Processing Record 24 of Set 2 | biloela
# Processing Record 25 of Set 2 | treinta y tres
# Processing Record 26 of Set 2 | koutiala
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | meulaboh
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | asyut
# Processing Record 32 of Set 2 | muzhi
# Processing Record 33 of Set 2 | mantua
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | brisbane
# Processing Record 38 of Set 2 | cayenne
# Processing Record 39 of Set 2 | lata
# Processing Record 40 of Set 2 | walvis bay
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | dunedin
# Processing Record 43 of Set 2 | araouane
# Processing Record 44 of Set 2 | chapais
# Processing Record 45 of Set 2 | cabedelo
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | turayf
# Processing Record 48 of Set 2 | boende
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 3 | johnstown
# Processing Record 4 of Set 3 | leshukonskoye
# Processing Record 5 of Set 3 | inuvik
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | anadyr
# Processing Record 8 of Set 3 | platanos
# Processing Record 9 of Set 3 | richmond
# Processing Record 10 of Set 3 | rodionovo-nesvetayskaya
# Processing Record 11 of Set 3 | nemuro
# Processing Record 12 of Set 3 | aswan
# Processing Record 13 of Set 3 | karratha
# Processing Record 14 of Set 3 | yar-sale
# Processing Record 15 of Set 3 | ushuaia
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | oda
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | rundu
# Processing Record 21 of Set 3 | sao filipe
# Processing Record 22 of Set 3 | san cristobal
# Processing Record 23 of Set 3 | ahero
# Processing Record 24 of Set 3 | beoumi
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | rio gallegos
# Processing Record 27 of Set 3 | changping
# Processing Record 28 of Set 3 | keti bandar
# Processing Record 29 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | elko
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | clyde river
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | san quintin
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | popondetta
# Processing Record 38 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 3 | wajima
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | quang ngai
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | brae
# Processing Record 44 of Set 3 | vardo
# Processing Record 45 of Set 3 | hamilton
# Processing Record 46 of Set 3 | varkaus
# Processing Record 47 of Set 3 | albany
# Processing Record 48 of Set 3 | soroti
# Processing Record 49 of Set 3 | bambous virieux
# Processing Record 50 of Set 3 | mar del plata
# Processing Record 1 of Set 4 | victoria
# Processing Record 2 of Set 4 | plettenberg bay
# Processing Record 3 of Set 4 | calabozo
# Processing Record 4 of Set 4 | the pas
# Processing Record 5 of Set 4 | torbat-e jam
# Processing Record 6 of Set 4 | pacific grove
# Processing Record 7 of Set 4 | adrar
# Processing Record 8 of Set 4 | fairbanks
# Processing Record 9 of Set 4 | kasongo-lunda
# Processing Record 10 of Set 4 | puerto narino
# Processing Record 11 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 4 | nyuksenitsa
# Processing Record 13 of Set 4 | kodiak
# Processing Record 14 of Set 4 | coos bay
# Processing Record 15 of Set 4 | neiafu
# Processing Record 16 of Set 4 | kasongo
# Processing Record 17 of Set 4 | faya
# Processing Record 18 of Set 4 | burica
# City not found. Skipping...
# Processing Record 19 of Set 4 | ongandjera
# Processing Record 20 of Set 4 | harper
# Processing Record 21 of Set 4 | bondo
# Processing Record 22 of Set 4 | saint george
# Processing Record 23 of Set 4 | sur
# Processing Record 24 of Set 4 | belmonte
# Processing Record 25 of Set 4 | ahipara
# Processing Record 26 of Set 4 | alofi
# Processing Record 27 of Set 4 | mount isa
# Processing Record 28 of Set 4 | harnosand
# Processing Record 29 of Set 4 | kalemie
# Processing Record 30 of Set 4 | chakulia
# Processing Record 31 of Set 4 | pamanukan
# Processing Record 32 of Set 4 | wattegama
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | loanda
# Processing Record 35 of Set 4 | hatillo
# Processing Record 36 of Set 4 | rosetta
# Processing Record 37 of Set 4 | perbaungan
# Processing Record 38 of Set 4 | georgetown
# Processing Record 39 of Set 4 | komsomolskiy
# Processing Record 40 of Set 4 | aanekoski
# Processing Record 41 of Set 4 | havoysund
# Processing Record 42 of Set 4 | jijiga
# Processing Record 43 of Set 4 | zhezkazgan
# Processing Record 44 of Set 4 | sindor
# Processing Record 45 of Set 4 | husavik
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | nikolskoye
# Processing Record 48 of Set 4 | xichang
# Processing Record 49 of Set 4 | caxito
# Processing Record 50 of Set 4 | hilo
# Processing Record 1 of Set 5 | isangel
# Processing Record 2 of Set 5 | ganzhou
# Processing Record 3 of Set 5 | orlovskiy
# Processing Record 4 of Set 5 | port hawkesbury
# Processing Record 5 of Set 5 | saraland
# Processing Record 6 of Set 5 | ouadda
# Processing Record 7 of Set 5 | along
# Processing Record 8 of Set 5 | jinchang
# Processing Record 9 of Set 5 | lasa
# Processing Record 10 of Set 5 | toungoo
# City not found. Skipping...
# Processing Record 11 of Set 5 | college
# Processing Record 12 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 5 | teya
# Processing Record 14 of Set 5 | carnarvon
# Processing Record 15 of Set 5 | barroualie
# City not found. Skipping...
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | porto novo
# Processing Record 18 of Set 5 | lagunas
# Processing Record 19 of Set 5 | acarau
# Processing Record 20 of Set 5 | severo-kurilsk
# Processing Record 21 of Set 5 | natal
# Processing Record 22 of Set 5 | santa maria
# Processing Record 23 of Set 5 | sokoni
# Processing Record 24 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 5 | tual
# Processing Record 27 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 28 of Set 5 | jumla
# Processing Record 29 of Set 5 | kavieng
# Processing Record 30 of Set 5 | khurda
# Processing Record 31 of Set 5 | ahuimanu
# Processing Record 32 of Set 5 | nikki
# Processing Record 33 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 5 | sinjai
# Processing Record 35 of Set 5 | placerville
# Processing Record 36 of Set 5 | kudahuvadhoo
# Processing Record 37 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 5 | santa rosa
# Processing Record 39 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 5 | russell
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | camana
# Processing Record 43 of Set 5 | ust-tsilma
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | ixtapa
# Processing Record 46 of Set 5 | tessalit
# Processing Record 47 of Set 5 | morgantown
# Processing Record 48 of Set 5 | coquimbo
# Processing Record 49 of Set 5 | selizharovo
# Processing Record 50 of Set 5 | inhambane
# Processing Record 1 of Set 6 | nata
# Processing Record 2 of Set 6 | souris
# Processing Record 3 of Set 6 | maarianhamina
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | noumea
# Processing Record 6 of Set 6 | portland
# Processing Record 7 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | mayo
# Processing Record 10 of Set 6 | sechura
# Processing Record 11 of Set 6 | merauke
# Processing Record 12 of Set 6 | serramanna
# Processing Record 13 of Set 6 | palana
# Processing Record 14 of Set 6 | cap malheureux
# Processing Record 15 of Set 6 | orotukan
# Processing Record 16 of Set 6 | saskylakh
# Processing Record 17 of Set 6 | lima
# Processing Record 18 of Set 6 | kingaroy
# Processing Record 19 of Set 6 | guerrero negro
# Processing Record 20 of Set 6 | iki-burul
# Processing Record 21 of Set 6 | mungwi
# Processing Record 22 of Set 6 | brugg
# Processing Record 23 of Set 6 | novobiryusinskiy
# Processing Record 24 of Set 6 | nyurba
# Processing Record 25 of Set 6 | mahebourg
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | uarini
# Processing Record 28 of Set 6 | iqaluit
# Processing Record 29 of Set 6 | botwood
# Processing Record 30 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 6 | wawa
# Processing Record 32 of Set 6 | manadhoo
# Processing Record 33 of Set 6 | kidal
# Processing Record 34 of Set 6 | souillac
# Processing Record 35 of Set 6 | tombouctou
# Processing Record 36 of Set 6 | masallatah
# Processing Record 37 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 38 of Set 6 | staryy nadym
# Processing Record 39 of Set 6 | praia da vitoria
# Processing Record 40 of Set 6 | santa fe
# Processing Record 41 of Set 6 | ndago
# Processing Record 42 of Set 6 | binga
# Processing Record 43 of Set 6 | kachug
# Processing Record 44 of Set 6 | tiznit
# Processing Record 45 of Set 6 | chuy
# Processing Record 46 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 6 | birjand
# Processing Record 48 of Set 6 | port-gentil
# Processing Record 49 of Set 6 | hurricane
# Processing Record 50 of Set 6 | benguela
# Processing Record 1 of Set 7 | ostrovnoy
# Processing Record 2 of Set 7 | port-cartier
# Processing Record 3 of Set 7 | alice springs
# Processing Record 4 of Set 7 | nishihara
# Processing Record 5 of Set 7 | saldanha
# Processing Record 6 of Set 7 | kesova gora
# Processing Record 7 of Set 7 | flinders
# Processing Record 8 of Set 7 | rawson
# Processing Record 9 of Set 7 | hovd
# Processing Record 10 of Set 7 | nova olinda do norte
# Processing Record 11 of Set 7 | seydi
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | yaan
# Processing Record 14 of Set 7 | hobyo
# Processing Record 15 of Set 7 | katsuura
# Processing Record 16 of Set 7 | waddan
# Processing Record 17 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 7 | muravlenko
# Processing Record 19 of Set 7 | sosnovo-ozerskoye
# Processing Record 20 of Set 7 | samarai
# Processing Record 21 of Set 7 | jalingo
# Processing Record 22 of Set 7 | barranca
# Processing Record 23 of Set 7 | airai
# Processing Record 24 of Set 7 | tuatapere
# Processing Record 25 of Set 7 | luena
# Processing Record 26 of Set 7 | lompoc
# Processing Record 27 of Set 7 | kieta
# Processing Record 28 of Set 7 | nhulunbuy
# Processing Record 29 of Set 7 | barcelona
# Processing Record 30 of Set 7 | dan khun thot
# Processing Record 31 of Set 7 | bayji
# Processing Record 32 of Set 7 | khandyga
# Processing Record 33 of Set 7 | paita
# Processing Record 34 of Set 7 | bluefield
# Processing Record 35 of Set 7 | blagoyevo
# Processing Record 36 of Set 7 | georgiyevskoye
# Processing Record 37 of Set 7 | pronsk
# Processing Record 38 of Set 7 | beaupre
# Processing Record 39 of Set 7 | rafaela
# Processing Record 40 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 7 | septemvri
# Processing Record 42 of Set 7 | kavaratti
# Processing Record 43 of Set 7 | boyolangu
# Processing Record 44 of Set 7 | oistins
# Processing Record 45 of Set 7 | comodoro rivadavia
# Processing Record 46 of Set 7 | viedma
# Processing Record 47 of Set 7 | sinnamary
# Processing Record 48 of Set 7 | kungurtug
# Processing Record 49 of Set 7 | kihei
# Processing Record 50 of Set 7 | mpika
# Processing Record 1 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 8 | trairi
# Processing Record 3 of Set 8 | elk city
# Processing Record 4 of Set 8 | chulman
# Processing Record 5 of Set 8 | gorontalo
# Processing Record 6 of Set 8 | cidreira
# Processing Record 7 of Set 8 | anuchino
# Processing Record 8 of Set 8 | prince rupert
# Processing Record 9 of Set 8 | kristiansund
# Processing Record 10 of Set 8 | verkhnevilyuysk
# Processing Record 11 of Set 8 | corsicana
# Processing Record 12 of Set 8 | upington
# Processing Record 13 of Set 8 | guabito
# Processing Record 14 of Set 8 | helena
# Processing Record 15 of Set 8 | kalmunai
# Processing Record 16 of Set 8 | farmington
# Processing Record 17 of Set 8 | ponta do sol
# Processing Record 18 of Set 8 | udimskiy
# Processing Record 19 of Set 8 | marystown
# Processing Record 20 of Set 8 | nantucket
# Processing Record 21 of Set 8 | lishan
# Processing Record 22 of Set 8 | benalla
# Processing Record 23 of Set 8 | taoudenni
# Processing Record 24 of Set 8 | la primavera
# Processing Record 25 of Set 8 | priladozhskiy
# Processing Record 26 of Set 8 | imbituba
# Processing Record 27 of Set 8 | khowst
# Processing Record 28 of Set 8 | aleksandrovsk-sakhalinskiy
# Processing Record 29 of Set 8 | ilhabela
# Processing Record 30 of Set 8 | yuli
# Processing Record 31 of Set 8 | wenling
# Processing Record 32 of Set 8 | tefe
# Processing Record 33 of Set 8 | darhan
# Processing Record 34 of Set 8 | the valley
# Processing Record 35 of Set 8 | tommot
# Processing Record 36 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 37 of Set 8 | seredka
# Processing Record 38 of Set 8 | mecca
# Processing Record 39 of Set 8 | mae sot
# Processing Record 40 of Set 8 | constitucion
# Processing Record 41 of Set 8 | vestmannaeyjar
# Processing Record 42 of Set 8 | ketchikan
# Processing Record 43 of Set 8 | narsaq
# Processing Record 44 of Set 8 | jinxiang
# Processing Record 45 of Set 8 | seymchan
# Processing Record 46 of Set 8 | ulaanbaatar
# Processing Record 47 of Set 8 | puerto colombia
# Processing Record 48 of Set 8 | luanda
# Processing Record 49 of Set 8 | cabo san lucas
# Processing Record 50 of Set 8 | lazaro cardenas
# Processing Record 1 of Set 9 | mount gambier
# Processing Record 2 of Set 9 | yasnogorsk
# Processing Record 3 of Set 9 | minggang
# Processing Record 4 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 9 | hailey
# Processing Record 6 of Set 9 | hambantota
# Processing Record 7 of Set 9 | vangaindrano
# Processing Record 8 of Set 9 | mitu
# Processing Record 9 of Set 9 | luderitz
# Processing Record 10 of Set 9 | kuching
# Processing Record 11 of Set 9 | muros
# Processing Record 12 of Set 9 | corn island
# Processing Record 13 of Set 9 | veraval
# Processing Record 14 of Set 9 | naze
# Processing Record 15 of Set 9 | pangnirtung
# Processing Record 16 of Set 9 | evensk
# Processing Record 17 of Set 9 | moron
# Processing Record 18 of Set 9 | tabou
# Processing Record 19 of Set 9 | port blair
# Processing Record 20 of Set 9 | key largo
# Processing Record 21 of Set 9 | ballina
# Processing Record 22 of Set 9 | melnikovo
# Processing Record 23 of Set 9 | esperance
# Processing Record 24 of Set 9 | cambridge
# Processing Record 25 of Set 9 | qeshm
# Processing Record 26 of Set 9 | baruun-urt
# Processing Record 27 of Set 9 | katav-ivanovsk
# Processing Record 28 of Set 9 | morehead
# Processing Record 29 of Set 9 | korla
# Processing Record 30 of Set 9 | bereda
# Processing Record 31 of Set 9 | yabrud
# Processing Record 32 of Set 9 | takestan
# Processing Record 33 of Set 9 | codrington
# Processing Record 34 of Set 9 | wuwei
# Processing Record 35 of Set 9 | santa cruz cabralia
# Processing Record 36 of Set 9 | sangar
# Processing Record 37 of Set 9 | lesnoy
# Processing Record 38 of Set 9 | berlevag
# Processing Record 39 of Set 9 | suntar
# Processing Record 40 of Set 9 | tocopilla
# Processing Record 41 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 9 | dryden
# Processing Record 43 of Set 9 | wana
# Processing Record 44 of Set 9 | bethel
# Processing Record 45 of Set 9 | ulaangom
# Processing Record 46 of Set 9 | xiaoweizhai
# Processing Record 47 of Set 9 | beaufort
# Processing Record 48 of Set 9 | naryan-mar
# Processing Record 49 of Set 9 | chara
# Processing Record 50 of Set 9 | mountain home
# Processing Record 1 of Set 10 | longyearbyen
# Processing Record 2 of Set 10 | port antonio
# Processing Record 3 of Set 10 | biak
# Processing Record 4 of Set 10 | prieska
# Processing Record 5 of Set 10 | sao mateus
# Processing Record 6 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 10 | byron bay
# Processing Record 8 of Set 10 | sao joao da barra
# Processing Record 9 of Set 10 | athabasca
# Processing Record 10 of Set 10 | sandwick
# Processing Record 11 of Set 10 | ambatofinandrahana
# Processing Record 12 of Set 10 | bogorodskoye
# Processing Record 13 of Set 10 | maceio
# Processing Record 14 of Set 10 | ponnampet
# Processing Record 15 of Set 10 | kruisfontein
# Processing Record 16 of Set 10 | ihosy
# Processing Record 17 of Set 10 | aban
# Processing Record 18 of Set 10 | mundo nuevo
# Processing Record 19 of Set 10 | ayan
# Processing Record 20 of Set 10 | aklavik
# Processing Record 21 of Set 10 | vinh
# Processing Record 22 of Set 10 | manakara
# Processing Record 23 of Set 10 | lodja
# Processing Record 24 of Set 10 | puri
# Processing Record 25 of Set 10 | port victoria
# Processing Record 26 of Set 10 | antalaha
# Processing Record 27 of Set 10 | baiyin
# Processing Record 28 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 10 | cockburn town
# Processing Record 30 of Set 10 | malaya vishera
# Processing Record 31 of Set 10 | maumere
# Processing Record 32 of Set 10 | sola
# Processing Record 33 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 10 | mugango
# Processing Record 35 of Set 10 | vostok
# Processing Record 36 of Set 10 | waounde
# Processing Record 37 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 10 | yulara
# Processing Record 39 of Set 10 | nouakchott
# Processing Record 40 of Set 10 | gemena
# Processing Record 41 of Set 10 | valparaiso
# Processing Record 42 of Set 10 | champerico
# Processing Record 43 of Set 10 | houlton
# Processing Record 44 of Set 10 | coruripe
# Processing Record 45 of Set 10 | olafsvik
# Processing Record 46 of Set 10 | beroroha
# Processing Record 47 of Set 10 | lavrentiya
# Processing Record 48 of Set 10 | leeton
# Processing Record 49 of Set 10 | roma
# Processing Record 50 of Set 10 | buzmeyin
# Processing Record 1 of Set 11 | mazagao
# Processing Record 2 of Set 11 | samagaltay
# Processing Record 3 of Set 11 | tabukiniberu
# City not found. Skipping...
# Processing Record 4 of Set 11 | port macquarie
# Processing Record 5 of Set 11 | saint anthony
# Processing Record 6 of Set 11 | swan river
# Processing Record 7 of Set 11 | francisco sa
# Processing Record 8 of Set 11 | luba
# Processing Record 9 of Set 11 | playas
# Processing Record 10 of Set 11 | opuwo
# Processing Record 11 of Set 11 | biltine
# Processing Record 12 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 11 | jardim
# Processing Record 14 of Set 11 | ashcroft
# Processing Record 15 of Set 11 | marsh harbour
# Processing Record 16 of Set 11 | baghdad
# Processing Record 17 of Set 11 | kahului
# Processing Record 18 of Set 11 | amahai
# Processing Record 19 of Set 11 | batagay
# Processing Record 20 of Set 11 | bandar-e lengeh
# Processing Record 21 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 11 | half moon bay
# Processing Record 23 of Set 11 | karakose
# City not found. Skipping...
# Processing Record 24 of Set 11 | keuruu
# Processing Record 25 of Set 11 | winnemucca
# Processing Record 26 of Set 11 | doische
# Processing Record 27 of Set 11 | tsabong
# Processing Record 28 of Set 11 | hammerfest
# Processing Record 29 of Set 11 | raga
# Processing Record 30 of Set 11 | panubigan
# Processing Record 31 of Set 11 | tilichiki
# Processing Record 32 of Set 11 | bambanglipuro
# Processing Record 33 of Set 11 | san andres
# Processing Record 34 of Set 11 | syracuse
# Processing Record 35 of Set 11 | palmer
# Processing Record 36 of Set 11 | guia de isora
# Processing Record 37 of Set 11 | bukachacha
# Processing Record 38 of Set 11 | nhamunda
# Processing Record 39 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 11 | kulhudhuffushi
# Processing Record 41 of Set 11 | vila velha
# Processing Record 42 of Set 11 | beni suef
# Processing Record 43 of Set 11 | axim
# Processing Record 44 of Set 11 | moerai
# Processing Record 45 of Set 11 | tarko-sale
# Processing Record 46 of Set 11 | beringovskiy
# Processing Record 47 of Set 11 | bloemfontein
# Processing Record 48 of Set 11 | puerto ayacucho
# Processing Record 49 of Set 11 | abha
# Processing Record 50 of Set 11 | maslova pristan
# Processing Record 1 of Set 12 | nizhnyaya tavda
# Processing Record 2 of Set 12 | scottsbluff
# Processing Record 3 of Set 12 | bonthe
# Processing Record 4 of Set 12 | benjamin hill
# Processing Record 5 of Set 12 | luchenza
# Processing Record 6 of Set 12 | chapleau
# Processing Record 7 of Set 12 | kota belud
# Processing Record 8 of Set 12 | sehithwa
# Processing Record 9 of Set 12 | sadiqabad
# Processing Record 10 of Set 12 | nikko
# Processing Record 11 of Set 12 | banyuwangi
# Processing Record 12 of Set 12 | buluang
# Processing Record 13 of Set 12 | qurayyat
# Processing Record 14 of Set 12 | zhangjiakou
# Processing Record 15 of Set 12 | san patricio
# Processing Record 16 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 17 of Set 12 | pauini
# Processing Record 18 of Set 12 | te anau
# Processing Record 19 of Set 12 | rapid valley
# Processing Record 20 of Set 12 | piacabucu
# Processing Record 21 of Set 12 | waitati
# Processing Record 22 of Set 12 | balakhninskiy
# Processing Record 23 of Set 12 | itarema
# Processing Record 24 of Set 12 | takab
# Processing Record 25 of Set 12 | pokhara
# Processing Record 26 of Set 12 | ganganagar
# Processing Record 27 of Set 12 | rio de janeiro
# Processing Record 28 of Set 12 | ponot
# Processing Record 29 of Set 12 | haines junction
# Processing Record 30 of Set 12 | aykhal
# Processing Record 31 of Set 12 | joshimath
# Processing Record 32 of Set 12 | ust-nera
# Processing Record 33 of Set 12 | humaita
# Processing Record 34 of Set 12 | acapulco
# Processing Record 35 of Set 12 | ambilobe
# Processing Record 36 of Set 12 | roald
# Processing Record 37 of Set 12 | lumberton
# Processing Record 38 of Set 12 | quepos
# Processing Record 39 of Set 12 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 40 of Set 12 | poum
# Processing Record 41 of Set 12 | saint-joseph
# Processing Record 42 of Set 12 | zhangye
# Processing Record 43 of Set 12 | arlit
# Processing Record 44 of Set 12 | christchurch
# Processing Record 45 of Set 12 | lagoa
# Processing Record 46 of Set 12 | nekhayevskiy
# Processing Record 47 of Set 12 | vaitape
# Processing Record 48 of Set 12 | manggar
# Processing Record 49 of Set 12 | marzuq
# Processing Record 50 of Set 12 | mandalgovi
# Processing Record 1 of Set 13 | tucupita
# Processing Record 2 of Set 13 | uinskoye
# Processing Record 3 of Set 13 | oum hadjer
# Processing Record 4 of Set 13 | itoman
# Processing Record 5 of Set 13 | kaihua
# Processing Record 6 of Set 13 | ponto novo
# Processing Record 7 of Set 13 | matadi
# Processing Record 8 of Set 13 | port augusta
# Processing Record 9 of Set 13 | dubovskoye
# Processing Record 10 of Set 13 | turukhansk
# Processing Record 11 of Set 13 | kirkwall
# Processing Record 12 of Set 13 | ilheus
# Processing Record 13 of Set 13 | kayerkan
# Processing Record 14 of Set 13 | san carlos de bariloche
# Processing Record 15 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 16 of Set 13 | bonavista
# Processing Record 17 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 13 | abu dhabi
# Processing Record 19 of Set 13 | fuerte olimpo
# Processing Record 20 of Set 13 | gallup
# Processing Record 21 of Set 13 | marovoay
# Processing Record 22 of Set 13 | estelle
# Processing Record 23 of Set 13 | san vicente
# Processing Record 24 of Set 13 | homer
# Processing Record 25 of Set 13 | port moresby
# Processing Record 26 of Set 13 | saint-pierre
# Processing Record 27 of Set 13 | gobabis
# Processing Record 28 of Set 13 | novikovo
# Processing Record 29 of Set 13 | codajas
# Processing Record 30 of Set 13 | yanam
# Processing Record 31 of Set 13 | leningradskiy
# Processing Record 32 of Set 13 | praia
# Processing Record 33 of Set 13 | dongkan
# Processing Record 34 of Set 13 | miramar
# Processing Record 35 of Set 13 | barreirinha
# Processing Record 36 of Set 13 | passo fundo
# Processing Record 37 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 13 | setubal
# Processing Record 39 of Set 13 | saint-medard-en-jalles
# Processing Record 40 of Set 13 | defiance
# Processing Record 41 of Set 13 | sidi bin nur
# Processing Record 42 of Set 13 | campbell river
# Processing Record 43 of Set 13 | tucuman
# Processing Record 44 of Set 13 | manado
# Processing Record 45 of Set 13 | beyla
# Processing Record 46 of Set 13 | bushehr
# Processing Record 47 of Set 13 | shibetsu
# Processing Record 48 of Set 13 | juiz de fora
# Processing Record 49 of Set 13 | kondinskoye
# Processing Record 50 of Set 13 | tsimlyansk
# Processing Record 1 of Set 14 | kirakira
# Processing Record 2 of Set 14 | senneterre
# Processing Record 3 of Set 14 | nizwa
# Processing Record 4 of Set 14 | chermoz
# Processing Record 5 of Set 14 | jarjis
# City not found. Skipping...
# Processing Record 6 of Set 14 | puerto escondido
# Processing Record 7 of Set 14 | verkhoyansk
# Processing Record 8 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 14 | makakilo city
# Processing Record 10 of Set 14 | hirara
# Processing Record 11 of Set 14 | bafilo
# Processing Record 12 of Set 14 | taunggyi
# Processing Record 13 of Set 14 | chernyshevskiy
# Processing Record 14 of Set 14 | shimoda
# Processing Record 15 of Set 14 | sitka
# Processing Record 16 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 14 | richards bay
# Processing Record 18 of Set 14 | sao desiderio
# Processing Record 19 of Set 14 | otofuke
# Processing Record 20 of Set 14 | gamba
# Processing Record 21 of Set 14 | okhotsk
# Processing Record 22 of Set 14 | mombetsu
# Processing Record 23 of Set 14 | paramo
# Processing Record 24 of Set 14 | corinto
# Processing Record 25 of Set 14 | ust-koksa
# Processing Record 26 of Set 14 | amga
# Processing Record 27 of Set 14 | grootfontein
# Processing Record 28 of Set 14 | san ramon de la nueva oran
# Processing Record 29 of Set 14 | dickinson
# Processing Record 30 of Set 14 | laranjeiro
# Processing Record 31 of Set 14 | victor harbor
# Processing Record 32 of Set 14 | port hedland
# Processing Record 33 of Set 14 | nikolayevsk-na-amure
# Processing Record 34 of Set 14 | chor
# Processing Record 35 of Set 14 | comalcalco
# Processing Record 36 of Set 14 | manokwari
# Processing Record 37 of Set 14 | lewistown
# Processing Record 38 of Set 14 | roquetas de mar
# Processing Record 39 of Set 14 | shaping
# Processing Record 40 of Set 14 | peniche
# Processing Record 41 of Set 14 | gushikawa
# Processing Record 42 of Set 14 | tazovskiy
# Processing Record 43 of Set 14 | plaster rock
# Processing Record 44 of Set 14 | verkhnyaya maksakovka
# Processing Record 45 of Set 14 | puerto plata
# Processing Record 46 of Set 14 | skerries
# Processing Record 47 of Set 14 | chinsali
# Processing Record 48 of Set 14 | kashan
# Processing Record 49 of Set 14 | krasnouralsk
# Processing Record 50 of Set 14 | elbrus
# Processing Record 1 of Set 15 | itupiranga
# Processing Record 2 of Set 15 | gimli
# Processing Record 3 of Set 15 | jalu
# Processing Record 4 of Set 15 | fare
# Processing Record 5 of Set 15 | saint-francois
# Processing Record 6 of Set 15 | moree
# Processing Record 7 of Set 15 | trmice
# Processing Record 8 of Set 15 | namatanai
# Processing Record 9 of Set 15 | ipaba
# Processing Record 10 of Set 15 | dom pedrito
# Processing Record 11 of Set 15 | sokoto
# Processing Record 12 of Set 15 | balabac
# Processing Record 13 of Set 15 | enshi
# Processing Record 14 of Set 15 | lakatoro
# Processing Record 15 of Set 15 | elizabeth city
# Processing Record 16 of Set 15 | mayya
# Processing Record 17 of Set 15 | kuito
# Processing Record 18 of Set 15 | adre
# Processing Record 19 of Set 15 | camacha
# Processing Record 20 of Set 15 | encruzilhada do sul
# Processing Record 21 of Set 15 | amuntai
# Processing Record 22 of Set 15 | agadez
# Processing Record 23 of Set 15 | mutsu
# Processing Record 24 of Set 15 | kyshtovka
# Processing Record 25 of Set 15 | toora-khem
# Processing Record 26 of Set 15 | igarka
# Processing Record 27 of Set 15 | bell ville
# Processing Record 28 of Set 15 | mizdah
# Processing Record 29 of Set 15 | ust-kuyga
# Processing Record 30 of Set 15 | goderich
# Processing Record 31 of Set 15 | kassala
# Processing Record 32 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 15 | klamath falls
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
w_df = pd.DataFrame(city_data)
w_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Cherskiy  68.7500  161.3000     45.55        54           3        4.81
# 1    Kununurra -15.7667  128.7333    100.38        30          40        4.61
# 2        Yanji  42.9075  129.5078     70.45        47          51        6.93
# 3  Yellowknife  62.4560 -114.3525     52.32        76          20        5.75
# 4        Gagra  43.3283   40.2239     61.72        91         100        8.16
# 5      Rikitea -23.1203 -134.9692     73.08        72           3       14.16
# 6       Kuzino  57.0224   59.4412     58.26        63         100        4.61
# 7    Sanmenxia  34.7747  111.1814     81.59        17          36       20.22
# 8     La Ronge  55.1001 -105.2842     50.25        62           0       11.50
# 9      Atbasar  51.8000   68.3333     75.65        37           0        4.41
#
#   Country                 Date Current Description
# 0      RU  2022-09-22 05:43:14           clear sky
# 1      AU  2022-09-22 05:46:04    scattered clouds
# 2      CN  2022-09-22 05:46:04       broken clouds
# 3      CA  2022-09-22 05:42:41          few clouds
# 4      GE  2022-09-22 05:50:28     overcast clouds
# 5      PF  2022-09-22 05:41:25           clear sky
# 6      RU  2022-09-22 05:50:28     overcast clouds
# 7      CN  2022-09-22 05:50:29    scattered clouds
# 8      CA  2022-09-22 05:50:29           clear sky
# 9      KZ  2022-09-22 05:50:30           clear sky

# %%
new_column_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
w_df = w_df[new_column_order]
w_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0     Cherskiy      RU  2022-09-22 05:43:14  68.7500  161.3000     45.55
# 1    Kununurra      AU  2022-09-22 05:46:04 -15.7667  128.7333    100.38
# 2        Yanji      CN  2022-09-22 05:46:04  42.9075  129.5078     70.45
# 3  Yellowknife      CA  2022-09-22 05:42:41  62.4560 -114.3525     52.32
# 4        Gagra      GE  2022-09-22 05:50:28  43.3283   40.2239     61.72
# 5      Rikitea      PF  2022-09-22 05:41:25 -23.1203 -134.9692     73.08
# 6       Kuzino      RU  2022-09-22 05:50:28  57.0224   59.4412     58.26
# 7    Sanmenxia      CN  2022-09-22 05:50:29  34.7747  111.1814     81.59
# 8     La Ronge      CA  2022-09-22 05:50:29  55.1001 -105.2842     50.25
# 9      Atbasar      KZ  2022-09-22 05:50:30  51.8000   68.3333     75.65
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        54           3        4.81           clear sky
# 1        30          40        4.61    scattered clouds
# 2        47          51        6.93       broken clouds
# 3        76          20        5.75          few clouds
# 4        91         100        8.16     overcast clouds
# 5        72           3       14.16           clear sky
# 6        63         100        4.61     overcast clouds
# 7        17          36       20.22    scattered clouds
# 8        62           0       11.50           clear sky
# 9        37           0        4.41           clear sky

# %%
output_data_file = 'WeatherPy_Database.csv'
w_df.to_csv(output_data_file,index_label = 'City_ID')
